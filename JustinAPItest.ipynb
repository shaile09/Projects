# %%
import requests
import json
import pandas as pd

# %%
api_key = "XhNX92521J_CznXDhlJx8-fGw93UzjmrVnmC41ZVFfDIc0ePgHoMB472mNVNize3LCT7oPbr1ttiulBtGWhIi83SMORqaJaZDjDytarEPUA4bLQgDLj029H44_CPXnYx"
headers = {'Authorization': 'Bearer %s' % api_key}

# %%
# Yelp Business Details
url='https://api.yelp.com/v3/businesses/search'

# %%
# In the dictionary, term can take values like food, cafes or businesses like McDonalds
params = {'term':'seafood','location':'Chicago'}

# %%
req=requests.get(url, params=params, headers=headers)

# %%
# proceed only if the status code is 200
print('The status code is {}'.format(req.status_code))
# Out:
# The status code is 200

# %%
# printing the text from the response 
json.loads(req.text)
# Out:
# {'businesses': [{'id': 'YvWQMlMjtYmVmheH97tTlQ',
#    'alias': 'crab-house-all-you-can-eat-seafood-new-york',
#    'name': 'Crab House All You Can Eat Seafood',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DYOp1lRJel6kSKJgr80sKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crab-house-all-you-can-eat-seafood-new-york?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 92,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75961, 'longitude': -73.9698},
#    'transactions': [],
#    'location': {'address1': '135 E 55th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['135 E 55th St', 'New York, NY 10022']},
#    'phone': '+12123926400',
#    'display_phone': '(212) 392-6400',
#    'distance': 6366.563387489673},
#   {'id': 'ehUuSk5gPTCQmwS_ubgKRA',
#    'alias': 'upstate-craft-beer-and-oyster-bar-new-york-4',
#    'name': 'Upstate Craft Beer & Oyster Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RvnUVU7MF7DT0RzNL-EebQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/upstate-craft-beer-and-oyster-bar-new-york-4?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 1851,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.726373, 'longitude': -73.986557},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '95 1st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['95 1st Ave', 'New York, NY 10003']},
#    'phone': '+16467915400',
#    'display_phone': '(646) 791-5400',
#    'distance': 2416.715359115974},
#   {'id': 'wRHUJ69-f4CiV5BRY72mUg',
#    'alias': 'aqua-boil-new-york-2',
#    'name': 'Aqua Boil',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wREsz4nOI5oGdYrRiOG1uA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aqua-boil-new-york-2?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 230,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.763702, 'longitude': -73.988386},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '750 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['750 9th Ave', 'New York, NY 10019']},
#    'phone': '+12124647428',
#    'display_phone': '(212) 464-7428',
#    'distance': 6497.896610888184},
#   {'id': 'FpKdZAQ6ecHZW3_HdeGVdA',
#    'alias': 'lobster-house-all-you-can-eat-seafood-rego-park-30',
#    'name': 'Lobster House All You Can Eat Seafood',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HfKLjliYiIgsO2leCW321A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lobster-house-all-you-can-eat-seafood-rego-park-30?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 500,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.73122, 'longitude': -73.8637},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '95-25 Queens Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Rego Park',
#     'zip_code': '11374',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['95-25 Queens Blvd', 'Rego Park, NY 11374']},
#    'phone': '+17186350900',
#    'display_phone': '(718) 635-0900',
#    'distance': 11408.78798764327},
#   {'id': '1x2hn3e9sCCZca1cnRTpEg',
#    'alias': 'claw-daddys-brooklyn',
#    'name': "Claw Daddy's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ABHo2xn4dcpVspJkaQ_g-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/claw-daddys-brooklyn?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 466,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68561, 'longitude': -73.98035},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '31 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31 3rd Ave', 'Brooklyn, NY 11217']},
#    'phone': '+13473188893',
#    'display_phone': '(347) 318-8893',
#    'distance': 2500.3200581143838},
#   {'id': 'hfMtSdxRsC3JQP3yrm6nag',
#    'alias': 'claw-daddys-new-york',
#    'name': "Claw Daddy's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RCru71cTtO-TtqRw50rc2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/claw-daddys-new-york?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 1675,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.722071, 'longitude': -73.98847},
#    'transactions': ['pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '185 Orchard St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['185 Orchard St', 'New York, NY 10002']},
#    'phone': '+16465906816',
#    'display_phone': '(646) 590-6816',
#    'distance': 1912.7787900899964},
#   {'id': 'FC2uST9JpPCFmjDcMDVZMA',
#    'alias': 'naked-crab-flushing',
#    'name': 'Naked Crab',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Z-GoKlfo_En0pp_3XvYV_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/naked-crab-flushing?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 556,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7585, 'longitude': -73.83467},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '39-16 College Point Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39-16 College Point Blvd', 'Flushing, NY 11354']},
#    'phone': '+17188868777',
#    'display_phone': '(718) 886-8777',
#    'distance': 14682.428622174932},
#   {'id': 'LpVbI-E9C-CSp7WhU5h2Iw',
#    'alias': 'fishmarket-restaurant-new-york',
#    'name': 'Fishmarket Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ORkIXgOiqhen_B3PGCS_9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fishmarket-restaurant-new-york?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 547,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70717, 'longitude': -74.00192},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '111 South St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 South St', 'New York, NY 10038']},
#    'phone': '+19173638101',
#    'display_phone': '(917) 363-8101',
#    'distance': 671.0784555500173},
#   {'id': 'PxzhCMoWEIe2nrNz1ISq7w',
#    'alias': 'astoria-seafood-and-grill-astoria',
#    'name': 'Astoria Seafood and Grill',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zoTLUtTByvxoSTg9lKWEzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/astoria-seafood-and-grill-astoria?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 103,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76586, 'longitude': -73.91304},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '25-79 Steinway St',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25-79 Steinway St', 'Astoria, NY 11103']},
#    'phone': '+19177451715',
#    'display_phone': '(917) 745-1715',
#    'distance': 9594.654240202046},
#   {'id': 'v0DwpyNrKeS2ZhfMjVu8lg',
#    'alias': 'cajunsea-and-oyster-bar-new-york-4',
#    'name': 'CajunSea & Oyster Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zwvku94Cgs_qmsjrV5ATRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cajunsea-and-oyster-bar-new-york-4?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 1230,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7483352, 'longitude': -73.9867701},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '32 W 33rd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 W 33rd St', 'New York, NY 10001']},
#    'phone': '+12125647333',
#    'display_phone': '(212) 564-7333',
#    'distance': 4788.307644622303},
#   {'id': '8TfhQaCxux6Eq8SK8iqyoQ',
#    'alias': 'abuqir-seafood-astoria',
#    'name': 'Abuqir Seafood',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gL_xhfdC31xYMGGvnavkOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/abuqir-seafood-astoria?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 129,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7683, 'longitude': -73.9110794},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '24-19 Steinway St',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['24-19 Steinway St', 'Astoria, NY 11103']},
#    'phone': '+17182743474',
#    'display_phone': '(718) 274-3474',
#    'distance': 9899.685807181475},
#   {'id': 'd7_W8J8T0PESBsILMsGKGQ',
#    'alias': 'sea-wolf-brooklyn',
#    'name': 'Sea Wolf',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/p-BHa6lSSUvV4CjFw1a9qg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sea-wolf-brooklyn?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 450,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70683, 'longitude': -73.9228},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '19 Wyckoff Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 Wyckoff Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17183663272',
#    'display_phone': '(718) 366-3272',
#    'distance': 6029.7881830578535},
#   {'id': '4M3jBdELCcCKJl1mEnTxzQ',
#    'alias': 'lamias-fish-market-new-york-2',
#    'name': "Lamia's Fish Market",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/VaQRGrRnsxM9n4rgDrs_XA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lamias-fish-market-new-york-2?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 208,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.722979, 'longitude': -73.9825102},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'location': {'address1': '47 Ave B',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47 Ave B', 'New York, NY 10009']},
#    'phone': '+12127773650',
#    'display_phone': '(212) 777-3650',
#    'distance': 2188.0590330253954},
#   {'id': 'UvQr8V1dD_d6yRsMJi04wA',
#    'alias': 'shaking-crab-brooklyn-brooklyn-2',
#    'name': 'Shaking Crab- Brooklyn',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cvhgQU_UDdG-MYe9MZCwag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shaking-crab-brooklyn-brooklyn-2?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 323,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.675783, 'longitude': -73.981205},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '230 5th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['230 5th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+19293376140',
#    'display_phone': '(929) 337-6140',
#    'distance': 3479.335561241081},
#   {'id': 'UxeR0yfupdcMPQ2HnAhweg',
#    'alias': 'boilery-new-york',
#    'name': 'Boilery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ghdTZroNzipfJ43ZC__evw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boilery-new-york?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 116,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'raw_food', 'title': 'Live/Raw Food'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.79321, 'longitude': -73.971396},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'location': {'address1': '710 Amsterdam Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['710 Amsterdam Ave', 'New York, NY 10025']},
#    'phone': '+16467558968',
#    'display_phone': '(646) 755-8968',
#    'distance': 9947.380844934461},
#   {'id': 'jDq9PWUwrSdJ_k1tHUnKFg',
#    'alias': 'marina-seafood-and-restaurant-astoria',
#    'name': 'Marina Seafood & Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ye-OW8ynGWKj9rIhyl8gvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marina-seafood-and-restaurant-astoria?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 8,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7685223, 'longitude': -73.9109765},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '2415 Steinway St',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2415 Steinway St', 'Astoria, NY 11103']},
#    'phone': '+17184339516',
#    'display_phone': '(718) 433-9516',
#    'distance': 9932.75076190798},
#   {'id': 'RLJ5BUm89VySJWHHvmSzEQ',
#    'alias': 'fish-new-york',
#    'name': 'Fish',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/QHCCSi0oksz6GHwid2JKEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fish-new-york?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 1439,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.731734, 'longitude': -74.003463},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '280 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['280 Bleecker St', 'New York, NY 10014']},
#    'phone': '+12127272879',
#    'display_phone': '(212) 727-2879',
#    'distance': 3023.642097737965},
#   {'id': 'm0fvt59Gf-m-TABjyM4YGw',
#    'alias': 'brooklyn-bay-seafood-brooklyn',
#    'name': 'Brooklyn Bay Seafood',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8Ade0BqvCaoctv5jY6j6-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-bay-seafood-brooklyn?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 50,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6341653608713,
#     'longitude': -74.026490981364},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '7026 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7026 3rd Ave', 'Brooklyn, NY 11209']},
#    'phone': '+17183335835',
#    'display_phone': '(718) 333-5835',
#    'distance': 8378.192363129505},
#   {'id': 'ryvBsB9FrBBZDak87iGS1w',
#    'alias': 'the-seafire-grill-new-york-4',
#    'name': 'The Seafire Grill',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XfmiprKBLVpP5ukKd1GnrA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-seafire-grill-new-york-4?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 1278,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7547012104496,
#     'longitude': -73.972255513072},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '158 E 48th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['158 E 48th St', 'New York, NY 10017']},
#    'phone': '+12129353785',
#    'display_phone': '(212) 935-3785',
#    'distance': 5783.28147646515},
#   {'id': '5jfJyABI5zAUk79IZXHtrw',
#    'alias': 'el-puerto-seafood-new-york',
#    'name': 'El Puerto Seafood',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/izfQhLfhYPuDp2oUBY2vRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-puerto-seafood-new-york?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 88,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8140258789062,
#     'longitude': -73.956413269043},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '511 W 125th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['511 W 125th St', 'New York, NY 10027']},
#    'phone': '+12128657676',
#    'display_phone': '(212) 865-7676',
#    'distance': 12489.051109839502}],
#  'total': 12200,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
url = "https://api.yelp.com/v3/businesses/FEVQpbOPOwAPNIgO7D3xxw/reviews"
req = requests.get(url, headers=headers)
print('the status code is {}'.format(req.status_code))
# Out:
# the status code is 200

# %%
json.loads(req.text)
# Out:
# {'reviews': [{'id': 'rGXGg3iffwFfj8gTEmEGTw',
#    'url': 'https://www.yelp.com/biz/shake-shack-new-york-2?adjust_creative=2FKww-gS4O2oekwQaqaa-A&hrid=rGXGg3iffwFfj8gTEmEGTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'text': "My husband and I have tried Shake Shack at the Palo Alto location in the Bay, but after having it here and comparing the two, it's definitely juicier and...",
#    'rating': 5,
#    'time_created': '2019-10-31 15:19:02',
#    'user': {'id': 'mxAgIY8-1aMai_Nb4WQxTQ',
#     'profile_url': 'https://www.yelp.com/user_details?userid=mxAgIY8-1aMai_Nb4WQxTQ',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/0ytPU3oLLu71peD_Nbb7ew/o.jpg',
#     'name': 'Rachel L.'}},
#   {'id': 'N8QvSeRdhlBqZalGejozkw',
#    'url': 'https://www.yelp.com/biz/shake-shack-new-york-2?adjust_creative=2FKww-gS4O2oekwQaqaa-A&hrid=N8QvSeRdhlBqZalGejozkw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'text': 'Apparently this thing called Shake Shack opened up and got super popular after I moved away from New York, and despite it making its way out to California,...',
#    'rating': 3,
#    'time_created': '2020-04-05 20:05:15',
#    'user': {'id': 'pqVAV_4q0yEmVZGMHIcIag',
#     'profile_url': 'https://www.yelp.com/user_details?userid=pqVAV_4q0yEmVZGMHIcIag',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/evdxNCm17lXbVVdN9R3Y9A/o.jpg',
#     'name': 'Matt F.'}},
#   {'id': '572oD7S8X4v0m8b1EFZgIQ',
#    'url': 'https://www.yelp.com/biz/shake-shack-new-york-2?adjust_creative=2FKww-gS4O2oekwQaqaa-A&hrid=572oD7S8X4v0m8b1EFZgIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'text': "I love this location, it's wonderful to sit in the park and enjoy some yummy food.... provided you get your food. I ordered a burger and a shake, paid,...",
#    'rating': 2,
#    'time_created': '2020-03-17 14:54:16',
#    'user': {'id': 'myBGjHJ9EhE9pyeodWw2Mg',
#     'profile_url': 'https://www.yelp.com/user_details?userid=myBGjHJ9EhE9pyeodWw2Mg',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/gOvxN8s6TJ0_yVfzDf5PXA/o.jpg',
#     'name': 'Nuna C.'}}],
#  'total': 5576,
#  'possible_languages': ['fr', 'en', 'zh', 'pt', 'de', 'it', 'sv', 'ja', 'es']}
