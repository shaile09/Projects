# %%
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
api_key = "XhNX92521J_CznXDhlJx8-fGw93UzjmrVnmC41ZVFfDIc0ePgHoMB472mNVNize3LCT7oPbr1ttiulBtGWhIi83SMORqaJaZDjDytarEPUA4bLQgDLj029H44_CPXnYx"
headers = {'Authorization': 'Bearer %s' % api_key}

# %%
# Yelp Business Details
url='https://api.yelp.com/v3/businesses/search'

# %%
# In the dictionary, term can take values like food, cafes or businesses like McDonalds
params = {'term':'mexican','location':'San Diego'}

# %%
req=requests.get(url, params=params, headers=headers)

# %%
# proceed only if the status code is 200
print('The status code is {}'.format(req.status_code))
# Out:
# The status code is 200

# %%
# printing the text from the response 
json.loads(req.text)
# Out:
# {'businesses': [{'id': 'mzLGnmpwtrIgUeplJtmOOw',
#    'alias': 'la-puerta-san-diego',
#    'name': 'La Puerta',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Xy4OllAF9-LlvoioAQEXwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-puerta-san-diego?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 3667,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.7110023498535,
#     'longitude': -117.161323547363},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '560 4th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92101',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['560 4th Ave', 'San Diego, CA 92101']},
#    'phone': '+16196963466',
#    'display_phone': '(619) 696-3466',
#    'distance': 8853.637819078784},
#   {'id': '8gtS-ugNXvM90hZgqjIWiw',
#    'alias': 'lolitas-mexican-food-san-diego-5',
#    'name': "Lolita's Mexican Food",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/th0z8c5H4kdrybAiL2LhyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lolitas-mexican-food-san-diego-5?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 2395,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.832264, 'longitude': -117.160599},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '7305 Clairemont Mesa Blvd',
#     'address2': 'Ste A',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['7305 Clairemont Mesa Blvd',
#      'Ste A',
#      'San Diego, CA 92111']},
#    'phone': '+18588747983',
#    'display_phone': '(858) 874-7983',
#    'distance': 4676.0410374419325},
#   {'id': '43BHmEbS7eBRxC7MFnqv7Q',
#    'alias': 'las-cuatro-milpas-san-diego-2',
#    'name': 'Las Cuatro Milpas',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FO2K895XPJQ2JmRekZEuBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/las-cuatro-milpas-san-diego-2?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 2068,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.701918, 'longitude': -117.145135},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1857 Logan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92113',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1857 Logan Ave', 'San Diego, CA 92113']},
#    'phone': '+16192344460',
#    'display_phone': '(619) 234-4460',
#    'distance': 9893.033962715792},
#   {'id': 'hrBx3KOo-K6aCslL2pVWWg',
#    'alias': 'los-panchos-tacos-and-cantina-san-diego',
#    'name': 'Los Panchos Tacos & Cantina',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7SHMHIrDqKi6yFQX99Oslw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-panchos-tacos-and-cantina-san-diego?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 107,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.7497048550342,
#     'longitude': -117.16069453904},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '441 Washington St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92103',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['441 Washington St', 'San Diego, CA 92103']},
#    'phone': '+16192955828',
#    'display_phone': '(619) 295-5828',
#    'distance': 4585.776821954351},
#   {'id': 'EGj92CH6mWFiRvHB1zyMAw',
#    'alias': 'lucha-libre-gourmet-taco-shop-san-diego',
#    'name': 'Lucha Libre Gourmet Taco Shop',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NgHanwNXu1xSNAlY3z8T8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lucha-libre-gourmet-taco-shop-san-diego?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 7694,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.743229, 'longitude': -117.181628},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1810 W Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92103',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1810 W Washington St', 'San Diego, CA 92103']},
#    'phone': '+16192968226',
#    'display_phone': '(619) 296-8226',
#    'distance': 5860.274607644788},
#   {'id': '48IFYYRKXAlCn1JbCV3_bA',
#    'alias': 'king-and-queen-cantina-san-diego',
#    'name': 'King and Queen Cantina',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hBCuZ0DdoihGUROQOHpMGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/king-and-queen-cantina-san-diego?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 1784,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.720773, 'longitude': -117.1693471},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1490 Kettner Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92101',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1490 Kettner Blvd', 'San Diego, CA 92101']},
#    'phone': '+16197567864',
#    'display_phone': '(619) 756-7864',
#    'distance': 7891.162988111244},
#   {'id': 'fMWoLTioV_ttwKX90bSL1Q',
#    'alias': 'cocina-35-san-diego',
#    'name': 'Cocina 35',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/H9W5Tg14pPXXVMVNmmdIpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cocina-35-san-diego?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 978,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.7202896932569,
#     'longitude': -117.159230396319},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1435 6th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92101',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1435 6th Ave', 'San Diego, CA 92101']},
#    'phone': '+16194315611',
#    'display_phone': '(619) 431-5611',
#    'distance': 7830.189442874606},
#   {'id': 'kiOIwpD1hVTr289Zt80AfA',
#    'alias': 'la-perla-cocina-mexicana-san-diego',
#    'name': 'La Perla Cocina Mexicana',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5RO0YIPRytOqenBXslbjYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-perla-cocina-mexicana-san-diego?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 644,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.7982481, 'longitude': -117.2563848},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '745 Emerald St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['745 Emerald St', 'San Diego, CA 92109']},
#    'phone': '+18582743038',
#    'display_phone': '(858) 274-3038',
#    'distance': 9600.426646654969},
#   {'id': 'ssJJPFuV6tTDgHYe2w9csQ',
#    'alias': 'oscars-mexican-seafood-san-diego-3',
#    'name': 'Oscars Mexican Seafood',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nmtXm16znYiTmTIP5MQdBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oscars-mexican-seafood-san-diego-3?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 2778,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.808189, 'longitude': -117.260846},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '703 Turquoise St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['703 Turquoise St', 'San Diego, CA 92109']},
#    'phone': '+18584886392',
#    'display_phone': '(858) 488-6392',
#    'distance': 10169.337870676562},
#   {'id': 'bCDi6bD9bCISqFZ3OyDbOg',
#    'alias': 'vallarta-express-mexican-eatery-san-diego',
#    'name': 'Vallarta Express Mexican Eatery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/16XW_DoIgg6fm6PBCkL1yg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vallarta-express-mexican-eatery-san-diego?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 1304,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.821346282959,
#     'longitude': -117.182472229004},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '4277 Genesee Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4277 Genesee Ave', 'San Diego, CA 92117']},
#    'phone': '+18585696945',
#    'display_phone': '(858) 569-6945',
#    'distance': 4339.998618265366},
#   {'id': 'B52EkpFK0GVtiJd17qokzA',
#    'alias': 'las-panchitas-fresh-mexican-grill-san-diego-2',
#    'name': 'Las Panchitas Fresh Mexican Grill',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/pDVaupHHtX6-HB9X6RXnpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/las-panchitas-fresh-mexican-grill-san-diego-2?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 181,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.8082291369159,
#     'longitude': -117.160630822289},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3542 Ashford St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3542 Ashford St', 'San Diego, CA 92111']},
#    'phone': '+18588746710',
#    'display_phone': '(858) 874-6710',
#    'distance': 2056.825199380479},
#   {'id': 'wFl8oyege66SxWSCItg86Q',
#    'alias': 'ponces-mexican-restaurant-san-diego',
#    'name': "Ponce's Mexican Restaurant",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1DbgOyk4UZSSa8qwrxlDBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ponces-mexican-restaurant-san-diego?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 1260,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.7634312168435,
#     'longitude': -117.108215567666},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '4050 Adams Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92116',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4050 Adams Ave', 'San Diego, CA 92116']},
#    'phone': '+16192824413',
#    'display_phone': '(619) 282-4413',
#    'distance': 5243.545989174968},
#   {'id': 'zCP7tTuUPkw9PeiyOp8FTw',
#    'alias': 'el-zarape-san-diego',
#    'name': 'El Zarape',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4YdLldak_WwdFSGaLHXrfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-zarape-san-diego?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 2633,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.76179, 'longitude': -117.14663},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '4642 Park Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92116',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4642 Park Blvd', 'San Diego, CA 92116']},
#    'phone': '+16196921652',
#    'display_phone': '(619) 692-1652',
#    'distance': 3276.8367722842063},
#   {'id': 'c2iFpIROV9OVK3wd24J0Tw',
#    'alias': 'la-vecindad-san-diego-2',
#    'name': 'La Vecindad',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/y6A_h6SpE8WA1oCgDhQyPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-vecindad-san-diego-2?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 944,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.7476563, 'longitude': -117.1602513},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '3827 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92103',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3827 5th Ave', 'San Diego, CA 92103']},
#    'phone': '+16195012885',
#    'display_phone': '(619) 501-2885',
#    'distance': 4819.13577936874},
#   {'id': 'xsm2uqj58l8QTqHxRgbMHQ',
#    'alias': 'california-burritos-san-diego',
#    'name': 'California Burritos',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DsdYoaSwKuxUhiULyoRQrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/california-burritos-san-diego?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 789,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.79333, 'longitude': -117.15598},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '7754 Starling Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92123',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['7754 Starling Dr', 'San Diego, CA 92123']},
#    'phone': '+18585691600',
#    'display_phone': '(858) 569-1600',
#    'distance': 370.6358028129525},
#   {'id': 'yeUrPbgYzfSC2YKRv9N-LA',
#    'alias': 'ortegas-bistro-san-diego',
#    'name': "Ortega's Bistro",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/iOnzgqf_v_0haEtgd999kw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ortegas-bistro-san-diego?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 1016,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.7480807767565,
#     'longitude': -117.163241931283},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '141 University Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92103',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['141 University Ave', 'San Diego, CA 92103']},
#    'phone': '+16196924200',
#    'display_phone': '(619) 692-4200',
#    'distance': 4801.491671311315},
#   {'id': 'IFSEy6J-0Ob5cwkr65SqPQ',
#    'alias': 'maritzas-mexican-food-restaurant-san-diego',
#    'name': "Maritza's Mexican Food Restaurant",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/X1NNsH2sJZcysMcSxbuR1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maritzas-mexican-food-restaurant-san-diego?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 301,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.8074153261934,
#     'longitude': -117.18348261393},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3582 Mount Acadia Blvd',
#     'address2': 'Ste D',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3582 Mount Acadia Blvd',
#      'Ste D',
#      'San Diego, CA 92111']},
#    'phone': '+18582798866',
#    'display_phone': '(858) 279-8866',
#    'distance': 3325.6137021773216},
#   {'id': 'O4r43qZXZu4BR6xHKxUsxw',
#    'alias': 'casa-machado-san-diego-2',
#    'name': 'Casa Machado',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JyUSp49lHdoR299ottAiQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-machado-san-diego-2?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 359,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.8127463641505,
#     'longitude': -117.141326581159},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '3750 John J Montgomery Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92123',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3750 John J Montgomery Dr', 'San Diego, CA 92123']},
#    'phone': '+18582924716',
#    'display_phone': '(858) 292-4716',
#    'distance': 2739.0799053032038},
#   {'id': 'HyOklQilKbyfM40nuFaMvg',
#    'alias': 'yesenias-mexican-food-san-diego',
#    'name': "Yesenia's Mexican Food",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yGvgEyfAjUaHvmF0w5v4hw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yesenias-mexican-food-san-diego?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 677,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.983072101016,
#     'longitude': -117.074153423309},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '12075 Carmel Mountain Rd',
#     'address2': 'Ste 208',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92128',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['12075 Carmel Mountain Rd',
#      'Ste 208',
#      'San Diego, CA 92128']},
#    'phone': '+18583858931',
#    'display_phone': '(858) 385-8931',
#    'distance': 22669.1448938142},
#   {'id': 'ix7cpqUC1Dk3BVeyGv_RFw',
#    'alias': 'casa-guadalajara-san-diego',
#    'name': 'Casa Guadalajara',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ovz1R40xyBakjVq6EQcovw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-guadalajara-san-diego?adjust_creative=2FKww-gS4O2oekwQaqaa-A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2FKww-gS4O2oekwQaqaa-A',
#    'review_count': 2294,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 32.75689, 'longitude': -117.19807},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '4105 Taylor St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4105 Taylor St', 'San Diego, CA 92110']},
#    'phone': '+16192955111',
#    'display_phone': '(619) 295-5111',
#    'distance': 5569.634047234326}],
#  'total': 3500,
#  'region': {'center': {'longitude': -117.15408325195312,
#    'latitude': 32.790569394537286}}}

# %%
url = "https://api.yelp.com/v3/businesses/FEVQpbOPOwAPNIgO7D3xxw/reviews"
req = requests.get(url, headers=headers)
print('the status code is {}'.format(req.status_code))
# Out:
# the status code is 200

# %%
data = json.loads(req.text)

# %%
data['reviews']
# Out:
# [{'id': 'rGXGg3iffwFfj8gTEmEGTw',
#   'url': 'https://www.yelp.com/biz/shake-shack-new-york-2?adjust_creative=2FKww-gS4O2oekwQaqaa-A&hrid=rGXGg3iffwFfj8gTEmEGTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=2FKww-gS4O2oekwQaqaa-A',
#   'text': "My husband and I have tried Shake Shack at the Palo Alto location in the Bay, but after having it here and comparing the two, it's definitely juicier and...",
#   'rating': 5,
#   'time_created': '2019-10-31 15:19:02',
#   'user': {'id': 'mxAgIY8-1aMai_Nb4WQxTQ',
#    'profile_url': 'https://www.yelp.com/user_details?userid=mxAgIY8-1aMai_Nb4WQxTQ',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/0ytPU3oLLu71peD_Nbb7ew/o.jpg',
#    'name': 'Rachel L.'}},
#  {'id': 'N8QvSeRdhlBqZalGejozkw',
#   'url': 'https://www.yelp.com/biz/shake-shack-new-york-2?adjust_creative=2FKww-gS4O2oekwQaqaa-A&hrid=N8QvSeRdhlBqZalGejozkw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=2FKww-gS4O2oekwQaqaa-A',
#   'text': 'Apparently this thing called Shake Shack opened up and got super popular after I moved away from New York, and despite it making its way out to California,...',
#   'rating': 3,
#   'time_created': '2020-04-05 20:05:15',
#   'user': {'id': 'pqVAV_4q0yEmVZGMHIcIag',
#    'profile_url': 'https://www.yelp.com/user_details?userid=pqVAV_4q0yEmVZGMHIcIag',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/evdxNCm17lXbVVdN9R3Y9A/o.jpg',
#    'name': 'Matt F.'}},
#  {'id': '572oD7S8X4v0m8b1EFZgIQ',
#   'url': 'https://www.yelp.com/biz/shake-shack-new-york-2?adjust_creative=2FKww-gS4O2oekwQaqaa-A&hrid=572oD7S8X4v0m8b1EFZgIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=2FKww-gS4O2oekwQaqaa-A',
#   'text': "I love this location, it's wonderful to sit in the park and enjoy some yummy food.... provided you get your food. I ordered a burger and a shake, paid,...",
#   'rating': 2,
#   'time_created': '2020-03-17 14:54:16',
#   'user': {'id': 'myBGjHJ9EhE9pyeodWw2Mg',
#    'profile_url': 'https://www.yelp.com/user_details?userid=myBGjHJ9EhE9pyeodWw2Mg',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/gOvxN8s6TJ0_yVfzDf5PXA/o.jpg',
#    'name': 'Nuna C.'}}]

# %%
df = pd.DataFrame.from_dict(json_normalize(data['reviews']), orient='columns')

# %%
df.head()
# Out:
#                        id                                                url  \
# 0  rGXGg3iffwFfj8gTEmEGTw  https://www.yelp.com/biz/shake-shack-new-york-...
# 1  N8QvSeRdhlBqZalGejozkw  https://www.yelp.com/biz/shake-shack-new-york-...
# 2  572oD7S8X4v0m8b1EFZgIQ  https://www.yelp.com/biz/shake-shack-new-york-...
#
#                                                 text  rating  \
# 0  My husband and I have tried Shake Shack at the...       5
# 1  Apparently this thing called Shake Shack opene...       3
# 2  I love this location, it's wonderful to sit in...       2
#
#           time_created                 user.id  \
# 0  2019-10-31 15:19:02  mxAgIY8-1aMai_Nb4WQxTQ
# 1  2020-04-05 20:05:15  pqVAV_4q0yEmVZGMHIcIag
# 2  2020-03-17 14:54:16  myBGjHJ9EhE9pyeodWw2Mg
#
#                                     user.profile_url  \
# 0  https://www.yelp.com/user_details?userid=mxAgI...
# 1  https://www.yelp.com/user_details?userid=pqVAV...
# 2  https://www.yelp.com/user_details?userid=myBGj...
#
#                                       user.image_url  user.name
# 0  https://s3-media4.fl.yelpcdn.com/photo/0ytPU3o...  Rachel L.
# 1  https://s3-media1.fl.yelpcdn.com/photo/evdxNCm...    Matt F.
# 2  https://s3-media1.fl.yelpcdn.com/photo/gOvxN8s...    Nuna C.
